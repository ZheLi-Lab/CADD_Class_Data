# %% [markdown]
# 1.Lipinski’s Rule of Five (Ro5)筛选

# %% [markdown]
# （1）设置路径并创建文件

# %%
import os
data_path = "data"
output_path = "output_data"
os.makedirs(data_path, exist_ok=True)
os.makedirs(output_path, exist_ok=True)

# %% [markdown]
# （2）定义及可视化示例分子

# %%
import pandas as pd
from rdkit.Chem import PandasTools

smiles_list = [
    "C[C@H]1OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(F)(F)F)ccn5)cc4F)c4c(N)nccn34)CC[C@@H]12",
    "C[C@]1(C(=O)O)CCC[C@@](C)(c2nc(-c3ccc(C(=O)Nc4cc(C(F)(F)F)ccn4)cc3)c3c(N)nccn23)C1",
    "C[C@@H]1OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(F)(F)F)ccn5)cc4)c4c(N)nccn34)CC[C@@H]12",
    "CC1(C)OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(F)(F)F)ccn5)cc4)c4c(N)nccn34)CC[C@H]21",
]
molecules = pd.DataFrame({"smiles": smiles_list})
# PandasTools.AddMoleculeColumnToFrame() 将从SMILES字符串生成的分子对象添加到数据框中
PandasTools.AddMoleculeColumnToFrame(molecules, "smiles")
molecules
# Out:
#                                               smiles  \
# 0  C[C@H]1OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C...
# 1  C[C@]1(C(=O)O)CCC[C@@](C)(c2nc(-c3ccc(C(=O)Nc4...
# 2  C[C@@H]1OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(...
# 3  CC1(C)OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(...
#
#                                                ROMol
# 0  <rdkit.Chem.rdchem.Mol object at 0x000001F0229...
# 1  <rdkit.Chem.rdchem.Mol object at 0x000001F0229...
# 2  <rdkit.Chem.rdchem.Mol object at 0x000001F0229...
# 3  <rdkit.Chem.rdchem.Mol object at 0x000001F0229...

# %% [markdown]
# （3）计算及输出示例分子Ro5性质

# %%
# 计算分子Ro5性质
import pandas as pd
from rdkit.Chem import Descriptors
from rdkit.Chem import PandasTools

smiles_list = [
    "C[C@H]1OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(F)(F)F)ccn5)cc4F)c4c(N)nccn34)CC[C@@H]12",
    "C[C@]1(C(=O)O)CCC[C@@](C)(c2nc(-c3ccc(C(=O)Nc4cc(C(F)(F)F)ccn4)cc3)c3c(N)nccn23)C1",
    "C[C@@H]1OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(F)(F)F)ccn5)cc4)c4c(N)nccn34)CC[C@@H]12",
    "CC1(C)OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(F)(F)F)ccn5)cc4)c4c(N)nccn34)CC[C@H]21",
]
molecules = pd.DataFrame({"smiles": smiles_list})
PandasTools.AddMoleculeColumnToFrame(molecules, "smiles")
# 使用 pandas 中的 apply() 方法将每个分子的性质计算到数据框中
# ExactMolWt() 函数计算分子的分子量
molecules["molecular_weight"] = molecules["ROMol"].apply(Descriptors.ExactMolWt)
# NumHAcceptors() 函数计算分子的氢键受体数
molecules["n_hba"] = molecules["ROMol"].apply(Descriptors.NumHAcceptors)
# NumHDonors() 函数计算分子的氢键供体数
molecules["n_hbd"] = molecules["ROMol"].apply(Descriptors.NumHDonors)
# MolLogP() 函数计算分子的分配系数
molecules["logp"] = molecules["ROMol"].apply(Descriptors.MolLogP)
display(molecules)
# Out:
#                                               smiles  \
# 0  C[C@H]1OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C...
# 1  C[C@]1(C(=O)O)CCC[C@@](C)(c2nc(-c3ccc(C(=O)Nc4...
# 2  C[C@@H]1OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(...
# 3  CC1(C)OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(...
#
#                                                ROMol  molecular_weight  n_hba  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x000001F023B...        569.179850      8
# 1  <rdkit.Chem.rdchem.Mol object at 0x000001F023B...        552.209673      7
# 2  <rdkit.Chem.rdchem.Mol object at 0x000001F023B...        551.189272      8
# 3  <rdkit.Chem.rdchem.Mol object at 0x000001F023B...        565.204922      8
#
#    n_hbd    logp
# 0      2  4.8704
# 1      3  5.5672
# 2      2  4.7313
# 3      2  5.1214

# %% [markdown]
# （4）将示例分子Ro5性质可视化为柱状图

# %% [markdown]
# （5）判断示例分子是否符合Ro5原则

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors

smiles_list = [
    "C[C@H]1OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(F)(F)F)ccn5)cc4F)c4c(N)nccn34)CC[C@@H]12",
    "C[C@]1(C(=O)O)CCC[C@@](C)(c2nc(-c3ccc(C(=O)Nc4cc(C(F)(F)F)ccn4)cc3)c3c(N)nccn23)C1",
    "C[C@@H]1OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(F)(F)F)ccn5)cc4)c4c(N)nccn34)CC[C@@H]12",
    "CC1(C)OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(F)(F)F)ccn5)cc4)c4c(N)nccn34)CC[C@H]21",
]

for smiles in smiles_list:
    molecule = Chem.MolFromSmiles(smiles)
    molecular_weight = Descriptors.ExactMolWt(molecule)
    n_hba = Descriptors.NumHAcceptors(molecule)
    n_hbd = Descriptors.NumHDonors(molecule)
    logp = Descriptors.MolLogP(molecule)
    condition = [
        molecular_weight <= 500,
        n_hba <= 10,
        n_hbd <= 5,
        logp <= 5
    ]
    print("对当前分子的 RO5 判断结果为：", condition)
    if sum(condition) < 3:
        print("当前分子不符合Ro5原则：", smiles)
    else:
        print("当前分子符合Ro5原则：", smiles)
# Out:
# 对当前分子的 RO5 判断结果为： [False, True, True, True]
# 当前分子符合Ro5原则： C[C@H]1OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(F)(F)F)ccn5)cc4F)c4c(N)nccn34)CC[C@@H]12
# 对当前分子的 RO5 判断结果为： [False, True, True, False]
# 当前分子不符合Ro5原则： C[C@]1(C(=O)O)CCC[C@@](C)(c2nc(-c3ccc(C(=O)Nc4cc(C(F)(F)F)ccn4)cc3)c3c(N)nccn23)C1
# 对当前分子的 RO5 判断结果为： [False, True, True, True]
# 当前分子符合Ro5原则： C[C@@H]1OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(F)(F)F)ccn5)cc4)c4c(N)nccn34)CC[C@@H]12
# 对当前分子的 RO5 判断结果为： [False, True, True, False]
# 当前分子不符合Ro5原则： CC1(C)OC(=O)N2C[C@H](c3nc(-c4ccc(C(=O)Nc5cc(C(F)(F)F)ccn5)cc4)c4c(N)nccn34)CC[C@H]21

# %% [markdown]
# （6）对BTK数据集进行Ro5筛选

# %%
import os
import pandas as pd
from rdkit.Chem import Descriptors
from rdkit.Chem import PandasTools

data_path = "data"
output_path = "output_data"
os.makedirs(data_path, exist_ok=True)
os.makedirs(output_path, exist_ok=True)
molecules_path = os.path.join(data_path, "BTK_compounds_Q06187.csv")
output_molecules_path = os.path.join(output_path, "BTK_compounds_Ro5_all.csv")
ro5_path       = os.path.join(output_path, "BTK_compounds_Ro5_filtered.csv")

if os.path.exists(molecules_path):
    print("文件已存在，路径为：", molecules_path)
else:
    import requests
    file_url = "https://raw.githubusercontent.com/ZheLi-Lab/CADD_Class_Data/main/chapter6/data/BTK_compounds_Q06187.csv"
    response = requests.get(file_url)
    with open(molecules_path, 'wb') as f:
        f.write(response.content)
        print("文件下载成功，保存路径为：", molecules_path)

# 使用 pd.read_csv() 函数读取CSV文件, index_col参数设置索引列
molecules = pd.read_csv(molecules_path, index_col=0)
PandasTools.AddMoleculeColumnToFrame(molecules, "smiles")
molecules["molecular_weight"] = molecules["ROMol"].apply(Descriptors.ExactMolWt)
molecules["n_hba"] = molecules["ROMol"].apply(Descriptors.NumHAcceptors)
molecules["n_hbd"] = molecules["ROMol"].apply(Descriptors.NumHDonors)
molecules["logp"] = molecules["ROMol"].apply(Descriptors.MolLogP)
# 筛选符合Ro5原则的分子
ro5_match = []
for molecule in molecules.iloc():
    condition = [
        molecule['molecular_weight'] <= 500,
        molecule['n_hba'] <= 10,
        molecule['n_hbd'] <= 5,
        molecule['logp'] <= 5
    ]
    if sum(condition) >= 3:
        ro5_match.append(True)
    else:
        ro5_match.append(False)
molecules["ro5_fulfilled"] = ro5_match
molecules.to_csv(output_molecules_path)
print("处理后的数据表已经保存在路径：", output_molecules_path)
filtered_molecules = molecules[molecules["ro5_fulfilled"]]
filtered_molecules.to_csv(ro5_path)
print("Ro5筛选后的数据表已经保存在路径：", ro5_path)
print("筛选数据集中总分子数：", len(molecules))
print("符合Ro5原则的分子数：", len(filtered_molecules))
# Out:
# 文件下载成功，保存路径为： data\BTK_compounds_Q06187.csv
# 处理后的数据表已经保存在路径： output_data\BTK_compounds_Ro5_all.csv
# Ro5筛选后的数据表已经保存在路径： output_data\BTK_compounds_Ro5_filtered.csv
# 筛选数据集中总分子数： 3047
# 符合Ro5原则的分子数： 2153

# %% [markdown]
# 2.Pan Assay Interference Compounds (PAINS)及Brenk过滤

# %%
import os
import pandas as pd
from rdkit import Chem
from rdkit.Chem.FilterCatalog import FilterCatalog
from rdkit.Chem.FilterCatalog import FilterCatalogParams

output_path = "output_data"
os.makedirs(output_path, exist_ok=True)
Ro5_all_path = os.path.join(output_path, "BTK_compounds_Ro5_all.csv")
BTK_compounds_Ro5_PAINS_all_path = os.path.join( output_path, "BTK_compounds_Ro5_PAINS_all.csv")
BTK_compounds_Ro5_PAINS_filtered_path = os.path.join( output_path, "BTK_compounds_Ro5_PAINS_filtered.csv")
if os.path.exists(Ro5_all_path):
    print("文件已存在，路径为：", Ro5_all_path)
else:
    import requests
    file_url = "https://raw.githubusercontent.com/ZheLi-Lab/CADD_Class_Data/main/chapter6/output/BTK_compounds_Ro5_all.csv"
    response = requests.get(file_url)
    with open(Ro5_all_path, 'wb') as f:
        f.write(response.content)
        print("文件下载成功，保存路径为：", Ro5_all_path)

BTK_data = pd.read_csv(Ro5_all_path, index_col=0)
# 创建一个过滤器目录参数对象
params = FilterCatalogParams()
# 添加 PAINS 过滤器目录
params.AddCatalog(FilterCatalogParams.FilterCatalogs.PAINS)
# 创建一个过滤器目录
catalog = FilterCatalog(params)
# 存储PAINS匹配结果的布尔值
pains_match = []  

for row in BTK_data.iloc():
    molecule = Chem.MolFromSmiles(row.smiles)
    entry = catalog.GetFirstMatch(molecule)  # 获得第一个匹配的PAINS
    if entry:
        pains_match.append(1)  # 表示有PAINS匹配
    else:
        pains_match.append(0)
# 将PAINS匹配结果的布尔值添加到BTK_data中
BTK_data['PAINS_match'] = pains_match
# 输出所有分子的 RO5 与 PAIN 结果到CSV文件
BTK_data.to_csv(BTK_compounds_Ro5_PAINS_all_path)
print("Ro5和PAINS计算数据表已经保存在路径：", BTK_compounds_Ro5_PAINS_all_path)
# 输出Ro5和PAINS过滤后的数据到CSV文件
filtered_data = BTK_data[
    (BTK_data['ro5_fulfilled'] == True) 
    & 
    (BTK_data['PAINS_match'] == 0)
]
filtered_data.to_csv(BTK_compounds_Ro5_PAINS_filtered_path)
print("Ro5和PAINS过滤后的数据表已经保存在路径：", BTK_compounds_Ro5_PAINS_filtered_path)
print("含有PAINS结构的分子数: ", sum(pains_match))
print("不含PAINS结构的分子数: ", len(pains_match) - sum(pains_match))
# Out:
# 文件已存在，路径为： output_data\BTK_compounds_Ro5_all.csv
# Ro5和PAINS计算数据表已经保存在路径： output_data\BTK_compounds_Ro5_PAINS_all.csv
# Ro5和PAINS过滤后的数据表已经保存在路径： output_data\BTK_compounds_Ro5_PAINS_filtered.csv
# 含有PAINS结构的分子数:  133
# 不含PAINS结构的分子数:  2914

# %% [markdown]
# （3）Brenk过滤

# %%
import os
import pandas as pd
from rdkit import Chem


data_path = "data"
output_path = "output_data"
os.makedirs(data_path, exist_ok=True)
os.makedirs(output_path, exist_ok=True)
# 下载数据集
BTK_compounds_Ro5_PAINS_all_path = os.path.join(output_path, "BTK_compounds_Ro5_PAINS_all.csv")
if os.path.exists(BTK_compounds_Ro5_PAINS_all_path):
    print("文件已存在，路径为：", BTK_compounds_Ro5_PAINS_all_path)
else:
    import requests
    file_url = "https://raw.githubusercontent.com/ZheLi-Lab/CADD_Class_Data/main/chapter6/output/BTK_compounds_Ro5_PAINS_all.csv"
    response = requests.get(file_url)
    with open(BTK_compounds_Ro5_PAINS_all_path, 'wb') as f:
        f.write(response.content)
        print("文件下载成功，保存路径为：", BTK_compounds_Ro5_PAINS_all_path)
BTK_data = pd.read_csv(BTK_compounds_Ro5_PAINS_all_path, index_col=0)
# 加载Brenk警示子结构文件
unwanted_substructures_path = os.path.join(data_path, "unwanted_substructures.csv")
if os.path.exists(unwanted_substructures_path):
    print("文件已存在，路径为：", unwanted_substructures_path)
else:
    import requests
    file_url = "https://raw.githubusercontent.com/ZheLi-Lab/CADD_Class_Data/main/chapter6/data/unwanted_substructures.csv"
    response = requests.get(file_url)
    with open(unwanted_substructures_path, 'wb') as f:
        f.write(response.content)
        print("文件下载成功，保存路径为：", unwanted_substructures_path)
substructures = pd.read_csv(unwanted_substructures_path, sep="\\s+")
substructures["molecule_object"] = substructures.smarts.apply(Chem.MolFromSmarts)

# 定义空列表用于存储匹配结果
matches = []
for index, row in BTK_data.iterrows():
    molecule = Chem.MolFromSmiles(row.smiles)
    # 初始化匹配的子结构列表为空，用于存储当前分子匹配到的所有警示子结构名称
    matched_substructures = []
    # 查找分子中的警示子结构
    for sub_id, substructure in substructures.iterrows():
        # 如果分子中含有警示子结构, 将匹配结果存储在 matches 列表中
        if molecule.HasSubstructMatch(substructure.molecule_object):
            matches.append({
                "chembl_id": row.IDs,
                "molecule_object": molecule,
                "substructure": substructure.molecule_object,
                "substructure_name": substructure["name"],
                "Brenk_match": 1
            })
            matched_substructures.append(substructure["name"])
    if matched_substructures:
        BTK_data.at[index, "Brenk_match"] = 1
        BTK_data.at[index, "Unwanted_Substructures"] = matched_substructures
    else:
        BTK_data.at[index, "Brenk_match"] = 0
# 将匹配结果转换为数据框
matches_df = pd.DataFrame(matches)
# 输出所有分子过滤结果到CSV文件
save_path = os.path.join(output_path, "BTK_compounds_Ro5_PAINS_Brenk_all.csv")
BTK_data.to_csv(save_path)
# 筛选符合过滤条件的分子（符合Ro5原则、PAINS匹配为0、Brenk匹配为0）
filtered_data = BTK_data[
    (BTK_data['ro5_fulfilled'] == True) 
    & 
    (BTK_data['PAINS_match'] == 0) 
    & 
    (BTK_data['Brenk_match'] == 0)
]
filtered_data = filtered_data.drop(columns=['Unwanted_Substructures'])
# 输出符合过滤条件的分子到CSV文件
save_path = os.path.join(output_path, "BTK_compounds_Ro5_PAINS_Brenk_filtered.csv")
filtered_data.to_csv(save_path)
# 输出过滤信息
count = len(BTK_data[BTK_data['Brenk_match'] == 1])
print(f"含警示结构分子数: {count}")
print(f"不含警示结构分子数: {len(BTK_data) - count}")
"""
警示结构展示：
"""
view_matches = matches_df.head(6)
highlight = []
for id, row in view_matches.iterrows():
    highlight.append(row.molecule_object.GetSubstructMatch(row.substructure))

# 使用 Chem.Draw.MolsToGridImage() 方法绘制分子网格图像
# 高亮显示匹配的警示子结构
Chem.Draw.MolsToGridImage(
    list(view_matches.molecule_object),
    highlightAtomLists=highlight,
    subImgSize=(400, 400)
)
# Out:
# 文件已存在，路径为： output_data\BTK_compounds_Ro5_PAINS_all.csv
# 文件下载成功，保存路径为： data\unwanted_substructures.csv
# 含警示结构分子数: 1416
# 不含警示结构分子数: 1631
